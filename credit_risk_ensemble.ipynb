# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Import the StandardScaler for Data Pre-Processing
from sklearn.preprocessing import StandardScaler

from imblearn.ensemble import BalancedRandomForestClassifier

# Import the Easy Ensemble Classifier (EEC)
from imblearn.ensemble import EasyEnsembleClassifier

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
X = df.copy()
X = X.drop(columns = 'loan_status')

# Create our target
y = df['loan_status']

# %% [markdown]
# # Encoding Data using One-Hot Encoding

# %%
# Encoding Data using `One-Hot Encoding`
X = pd.get_dummies(X)
X.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1    25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2    20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3    10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4    22000.0    0.1474       520.39     52000.0  18.76          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  issue_d_Mar-2019  \
# 0             0.0       8.0      0.0     1609.0  ...                 1
# 1             0.0      17.0      1.0    18368.0  ...                 1
# 2             0.0       8.0      0.0    13247.0  ...                 1
# 3             1.0      10.0      1.0    17996.0  ...                 1
# 4             1.0      14.0      0.0     9091.0  ...                 1
#
#    pymnt_plan_n  initial_list_status_f  initial_list_status_w  \
# 0             1                      0                      1
# 1             1                      0                      1
# 2             1                      0                      1
# 3             1                      0                      1
# 4             1                      0                      1
#
#    next_pymnt_d_Apr-2019  next_pymnt_d_May-2019  application_type_Individual  \
# 0                      0                      1                            1
# 1                      0                      1                            1
# 2                      0                      1                            1
# 3                      0                      1                            1
# 4                      0                      1                            1
#
#    application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# 0                           0                1                       1
# 1                           0                1                       1
# 2                           0                1                       1
# 3                           0                1                       1
# 4                           0                1                       1
#
# [5 rows x 95 columns]

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  issue_d_Mar-2019  pymnt_plan_n  \
# count   68817.000000  ...      68817.000000       68817.0
# mean    17604.142828  ...          0.177238           1.0
# std     21835.880400  ...          0.381873           0.0
# min         0.000000  ...          0.000000           1.0
# 25%      6293.000000  ...          0.000000           1.0
# 50%     12068.000000  ...          0.000000           1.0
# 75%     21735.000000  ...          0.000000           1.0
# max    587191.000000  ...          1.000000           1.0
#
#        initial_list_status_f  initial_list_status_w  next_pymnt_d_Apr-2019  \
# count           68817.000000           68817.000000           68817.000000
# mean                0.123879               0.876121               0.383161
# std                 0.329446               0.329446               0.486161
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               1.000000               0.000000
# 50%                 0.000000               1.000000               0.000000
# 75%                 0.000000               1.000000               1.000000
# max                 1.000000               1.000000               1.000000
#
#        next_pymnt_d_May-2019  application_type_Individual  \
# count           68817.000000                 68817.000000
# mean                0.616839                     0.860340
# std                 0.486161                     0.346637
# min                 0.000000                     0.000000
# 25%                 0.000000                     1.000000
# 50%                 1.000000                     1.000000
# 75%                 1.000000                     1.000000
# max                 1.000000                     1.000000
#
#        application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# count                68817.000000          68817.0                 68817.0
# mean                     0.139660              1.0                     1.0
# std                      0.346637              0.0                     0.0
# min                      0.000000              1.0                     1.0
# 25%                      0.000000              1.0                     1.0
# 50%                      0.000000              1.0                     1.0
# 75%                      0.000000              1.0                     1.0
# max                      1.000000              1.0                     1.0
#
# [8 rows x 95 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
# Split the X and y into X_train, X_test, y_train, y_test
# Create X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# Shape X_train
X_train.shape
# Out:
# (51612, 95)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
X_scaler = scaler.fit(X_train)

# %%
# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
brf.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/3576560135.py in <module>
#       1 # Resample the training data with the BalancedRandomForestClassifier
#       2 brf = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
# ----> 3 brf.fit(X_train_scaled, y_train)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/imblearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     433
#     434         # Remap output
# --> 435         _, self.n_features_ = X.shape
#     436
#     437         y = np.atleast_1d(y)
#
# AttributeError: can't set attribute

# %%
# Calculated the balanced accuracy score
y_pred = brf.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/195977119.py in <module>
#       1 # Calculated the balanced accuracy score
# ----> 2 y_pred = brf.predict(X_test_scaled)
#       3 balanced_accuracy_score(y_test, y_pred)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     806             The predicted classes.
#     807         """
# --> 808         proba = self.predict_proba(X)
#     809
#     810         if self.n_outputs_ == 1:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     856         all_proba = [
#     857             np.zeros((X.shape[0], j), dtype=np.float64)
# --> 858             for j in np.atleast_1d(self.n_classes_)
#     859         ]
#     860         lock = threading.Lock()
#
# AttributeError: 'BalancedRandomForestClassifier' object has no attribute 'n_classes_'

# %%
# Display the confusion matrix
pd.DataFrame(confusion_matrix(y_test, y_pred), 
            index = ["High Risk (Predicted Positive)", "Low Risk (Predicted Negative)"], 
            columns = ["Positive", "Negative"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/3253000409.py in <module>
#       1 # Display the confusion matrix
# ----> 2 pd.DataFrame(confusion_matrix(y_test, y_pred),
#       3             index = ["High Risk (Predicted Positive)", "Low Risk (Predicted Negative)"],
#       4             columns = ["Positive", "Negative"])
#
# NameError: name 'y_pred' is not defined

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/232817764.py in <module>
#       1 # Print the imbalanced classification report
# ----> 2 print(classification_report_imbalanced(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
# List the features sorted in descending order by feature importance
feature_importances = brf.feature_importances_ 
indices = np.argsort(feature_importances)[::-1]
for i in range(X.shape[1]):
    if len(X.columns.values[indices[i]])> 27: 
        print(f"{i:02d} {X.columns.values[indices[i]]}:\t({feature_importances[indices[i]]})")
    elif len(X.columns.values[indices[i]])> 25: 
        print(f"{i:02d} {X.columns.values[indices[i]]}:\t\t({feature_importances[indices[i]]})")
    elif len(X.columns.values[indices[i]])>24: 
        print(f"{i:02d} {X.columns.values[indices[i]]}:\t({feature_importances[indices[i]]})")
    elif len(X.columns.values[indices[i]])>19: 
        print(f"{i:02d} {X.columns.values[indices[i]]}:\t\t({feature_importances[indices[i]]})")
    elif len(X.columns.values[indices[i]])>11: 
        print(f"{i:02d} {X.columns.values[indices[i]]}:\t\t\t({feature_importances[indices[i]]})")
    elif len(X.columns.values[indices[i]])>9: 
        print(f"{i:02d} {X.columns.values[indices[i]]}:\t\t\t\t({feature_importances[indices[i]]})")
    elif len(X.columns.values[indices[i]])>8: 
        print(f"{i:02d} {X.columns.values[indices[i]]}:\t\t\t\t({feature_importances[indices[i]]})")        
    elif len(X.columns.values[indices[i]])<4: 
        print(f"{i:02d} {X.columns.values[indices[i]]}:\t\t\t\t\t({feature_importances[indices[i]]})")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/2472780755.py in <module>
#       1 # List the features sorted in descending order by feature importance
# ----> 2 feature_importances = brf.feature_importances_
#       3 indices = np.argsort(feature_importances)[::-1]
#       4 for i in range(X.shape[1]):
#       5     if len(X.columns.values[indices[i]])> 27:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in feature_importances_(self)
#     609         )(
#     610             delayed(getattr)(tree, "feature_importances_")
# --> 611             for tree in self.estimators_
#     612             if tree.tree_.node_count > 1
#     613         )
#
# AttributeError: 'BalancedRandomForestClassifier' object has no attribute 'estimators_'

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)
eec.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/2368692532.py in <module>
#       1 # Train the Classifier
#       2 eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)
# ----> 3 eec.fit(X_train_scaled, y_train)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/imblearn/ensemble/_easy_ensemble.py in fit(self, X, y)
#     221         # RandomUnderSampler is not supporting sample_weight. We need to pass
#     222         # None.
# --> 223         return self._fit(X, y, self.max_samples, sample_weight=None)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     335             max_features = self.max_features
#     336         elif isinstance(self.max_features, float):
# --> 337             max_features = self.max_features * self.n_features_in_
#     338         else:
#     339             raise ValueError("max_features must be int or float")
#
# AttributeError: 'EasyEnsembleClassifier' object has no attribute 'n_features_in_'

# %%
# Calculated the balanced accuracy score
y_pred = eec.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     821             try:
# --> 822                 tasks = self._ready_batches.get(block=False)
#     823             except queue.Empty:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/queue.py in get(self, block, timeout)
#     166                 if not self._qsize():
# --> 167                     raise Empty
#     168             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/3571217757.py in <module>
#       1 # Calculated the balanced accuracy score
# ----> 2 y_pred = eec.predict(X_test_scaled)
#       3 balanced_accuracy_score(y_test, y_pred)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in predict(self, X)
#     742             The predicted classes.
#     743         """
# --> 744         predicted_probabilitiy = self.predict_proba(X)
#     745         return self.classes_.take((np.argmax(predicted_probabilitiy, axis=1)), axis=0)
#     746
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in predict_proba(self, X)
#     791                 self.n_classes_,
#     792             )
# --> 793             for i in range(n_jobs)
#     794         )
#     795
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     831                 big_batch_size = batch_size * n_jobs
#     832
# --> 833                 islice = list(itertools.islice(iterator, big_batch_size))
#     834                 if len(islice) == 0:
#     835                     return False
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in <genexpr>(.0)
#     791                 self.n_classes_,
#     792             )
# --> 793             for i in range(n_jobs)
#     794         )
#     795
#
# AttributeError: 'EasyEnsembleClassifier' object has no attribute 'estimators_'

# %%
# Display the confusion matrix
pd.DataFrame(confusion_matrix(y_test, y_pred), 
                         index = ["High Risk (Predicted Positive)", "Low RIsk (Predicted Negative)"], 
                         columns = ["Positive", "Negative"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/2870810193.py in <module>
#       1 # Display the confusion matrix
# ----> 2 pd.DataFrame(confusion_matrix(y_test, y_pred),
#       3                          index = ["High Risk (Predicted Positive)", "Low RIsk (Predicted Negative)"],
#       4                          columns = ["Positive", "Negative"])
#
# NameError: name 'y_pred' is not defined

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w1/48020hx94kn5jmxmf93_7lr80000gn/T/ipykernel_9606/232817764.py in <module>
#       1 # Print the imbalanced classification report
# ----> 2 print(classification_report_imbalanced(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
#     Easy Ensemble Classifier has a better balanced accuracy score of 92%
#
# 2. Which model had the best recall score?
#
#     Easy Ensemble Classifier has the best recall score.
#
# 3. Which model had the best geometric mean score?
#
#     Easy Ensemble Classifier has the best geometric mean score
#
# 4. What are the top three features?
#
# - total_rec_prncp
# - total_rec_int
# - total_pymnt_inv
